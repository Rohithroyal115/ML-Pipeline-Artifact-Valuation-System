# %%
import pandas as pd

df=pd.read_csv('../data/cleaned_data.csv')

# %%
df.drop(columns=['Unnamed: 0','desc_length'],inplace=True)
df.head()
# Out:
#    id item_type  weight_grams  height_cm  width_cm  depth_cm primary_material  \
# 0   1    amulet          7.00       4.00      2.00      1.00           bronze
# 1   2      ring          3.00       1.50      2.60      0.40           copper
# 2   3      ring          3.05       1.50      2.30      0.80            brass
# 3   4     crown        507.36      15.81      4.62      2.01           silver
# 4   5      ring          3.40       1.50      4.00      1.50         platinum
#
#   secondary_material gem_type  gem_count  ... restoration_status  \
# 0            leather  emerald          3  ...            cleaned
# 1               none     ruby          5  ...      reconstructed
# 2               bone  diamond          3  ...            cleaned
# 3              cloth     ruby          4  ...            cleaned
# 4               bone     ruby          1  ...           restored
#
#   authentication_status monetary_value_gold historical_significance  \
# ...

# %%
df.to_csv('../data/data.csv')

# %%
df.isnull().sum()
# Out:
# id                         0
# item_type                  0
# weight_grams               0
# height_cm                  0
# width_cm                   0
# depth_cm                   0
# primary_material           0
# secondary_material         0
# gem_type                   0
# gem_count                  0
# primary_color              0
# surface_texture            0
# rarity_level               0
# origin_culture             0
# creation_year              0
# has_inscription            0
# inscription_script         0
# pattern_type               0
# craftsmanship_level        0
# magic_enchanted            0
# environment_type           0
# oxidation_level            0
# restoration_status         0
# authentication_status      0
# monetary_value_gold        0
# historical_significance    0
# cursed_status              0
# shine_factor               0
# damage_resistance          0
# set_piece                  0
# description                0
# preservation_score         0
# ...

# %%
for col in df.columns:
    if df[col].dtype == 'O':
        print(df[col].unique())
# Out:
# ['amulet' 'ring' 'crown' 'doubloon' 'necklace' 'chalice' 'scepter'
#  'brooch']
# ['bronze' 'copper' 'brass' 'silver' 'platinum' 'gold' 'steel+ivory'
#  'copper+silver' 'steel+silver' 'steel' 'copper+gold' 'iron' 'steel+gold'
#  'iron+bone' 'steel+bronze' 'iron+gold' 'steel+bone' 'copper+bronze'
#  'copper+bone' 'iron+leather' 'iron+silver' 'copper+leather' 'iron+wood'
#  'iron+ivory' 'steel+leather' 'copper+ivory' 'platinum+wood' 'iron+cloth'
#  'steel+wood' 'iron+bronze' 'platinum+bone' 'copper+wood' 'gold+steel'
#  'steel+cloth' 'gold+iron' 'brass+ivory' 'platinum+ivory' 'copper+cloth'
#  'platinum+leather' 'brass+bone' 'iron+steel' 'steel+pearl' 'bronze+wood'
#  'platinum+gold' 'steel+diamond']
# ['leather' 'none' 'bone' 'cloth' 'wood' 'ivory' 'bronze' 'gold_trim'
#  'diamond' 'silver' 'silk' 'steel' 'emerald' 'iron' 'gold trim' 'sapphire'
#  'cloth trim' 'leather_wrap' 'pearl' 'ruby' 'silver trim' 'gold'
#  'royal blue velvet' 'topaz' 'copper trim' 'emerald-inlaid cloth'
# ...
